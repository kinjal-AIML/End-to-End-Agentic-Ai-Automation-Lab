# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **AgentChat API with Assistant Agent**

# %%
from autogen_agentchat.agents import AssistantAgent

# %% [markdown]
# ## Model

# %%
from dotenv import load_dotenv
import os
load_dotenv()
from autogen_ext.models.openai import OpenAIChatCompletionClient
open_router_api_key = os.getenv("OPEN_ROUTER_API_KEY")

# %% [markdown]
# ## **Model Accessing Form `Open Router`**

# %%
open_router_model_client =  OpenAIChatCompletionClient(
    base_url="https://openrouter.ai/api/v1",
    model="deepseek/deepseek-r1-0528:free",
    api_key = open_router_api_key,
    model_info={
        "family":'deepseek',
        "vision" :True,
        "function_calling":True,
        "json_output": False
    }
)

# %% [markdown]
# AutoGen AgentChat provides a set of preset Agents, each with variations in how an agent might respond to messages. All agents share the following attributes and methods:
#
# - **`name`**: The unique name of the agent.
#
# - **`description`**: The description of the agent in text.
#
# - **`run`**: The method that runs the agent given a task as a string or a list of messages, and returns a TaskResult. **Agents are expected to be stateful and this method is expected to be called with new messages, not complete history.**
#
# - **`run_stream`**: Same as run() but returns an iterator of messages that subclass BaseAgentEvent or BaseChatMessage followed by a TaskResult as the last item.

# %%
my_assistant = AssistantAgent(
    name="my_assistant",
    model_client=open_router_model_client,
    system_message="You are High school math teacher. Do not response in-depth if the question is not math related.",
    model_client_stream=True,
)

# %%
response = await my_assistant.run(
    task="hi, who are you?"
)
response
# Out:
# TaskResult(messages=[TextMessage(id='42e9d4a9-07bd-4c23-8676-d9d86cb83ab3', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 15, 9, 25, 22, 844125, tzinfo=datetime.timezone.utc), content='hi, who are you?', type='TextMessage'), TextMessage(id='b5112f50-ebde-4919-b335-e71bd54522f3', source='my_assistant', models_usage=RequestUsage(prompt_tokens=32, completion_tokens=276), metadata={}, created_at=datetime.datetime(2025, 7, 15, 9, 25, 43, 441033, tzinfo=datetime.timezone.utc), content="I'm your High School Math Assistant! I'm here to help with math-related questions only—anything from algebra and geometry to calculus or statistics. If you have a math problem, concept, or homework question, feel free to share it. 😊  \n\n*(Note: Since your question wasn't math-related, I kept this brief. Ask me anything math-related for a detailed response!)*", type='TextMessage')], stop_reason=None)
