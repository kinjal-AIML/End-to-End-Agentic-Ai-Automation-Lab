# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.ollama import OllamaChatCompletionClient

# %%
ollama_model_client = OllamaChatCompletionClient(model="llama3.1")

# %%
agent_1 = AssistantAgent(
    name="My_Assistant",
    model_client=ollama_model_client,
    system_message="You are a helpful ai assistant."
)

# %%
response = await agent_1.run(
    task = "Hi, my i'm Al Amin"
)

# %%
response.messages[-1].content
# Out:
# "Nice to meet you, Al Amin! How can I assist you today? Do you have any questions or topics you'd like to discuss? I'm here to help with anything from general knowledge to more specific queries. Feel free to ask me anything!"
